# %%
# import library ที่สำคัญ
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#------------ ถ้าใช้วิธี import data เข้ามา ให้ข้ามอันนี้ไป -----------------
# อันนี้คือหนูใส่ data ไว้ใน google drive ของหนูเองแล้วดึงมานะคะ เพื่อความสะดวกตอนดึงมาค่ะ
from google.colab import drive
drive.mount("/content/drive")
data = pd.read_csv('/content/drive/My Drive/data mining/hw2/titanic.csv')
data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# # ---------- แบบ import data เข้ามา -------------
# #load ข้อมูลเข้ามาเก็บใน datafram data
# data=pd.read_csv('titanic.csv')
# data

# %%
data.head()  #ลอง print ข้อมูลออกมาดู
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
# ดู shape ของข้อมูล
data.shape
# Out:
# (891, 12)

# %%
## ดูว่ามีค่า null หรือไม่ 
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# copy data เข้าที่ df เพื่อกันการไปเปลี่ยนตัวดาต้าจริง
df = data

# %%
# หลังจากใช้ .describe() จะตัดคอลัมน์ที่ไม่สามารถคำนวณได้ไปเลย พวกที่เป็นข้อมูลตัวอักษร 
# แต่ยังมีอีกหลายคอลัมน์ที่เป็น Categorical แต่ว่าบันทึกข้อมูลแบบตัวเลข ซึ่งจะได้ดังนี้ 
# noted ว่าตัวที่เป็น category ได้แก่ Pclass(1,2,3) PassengerId(1-891)  Survived(0,1)
df.describe() # ดูรายละเอียดของข้อมูล เห็นไดว่,า Survival เป็น categorical
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
#แสดงผลค่า mean med mode
print(df.mean())
print(df.median())
print(df.mode())
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64
#      PassengerId  Survived  Pclass  ...  Fare        Cabin  Embarked
# 0              1       0.0     3.0  ...  8.05      B96 B98         S
# 1              2       NaN     NaN  ...   NaN  C23 C25 C27       NaN
# 2              3       NaN     NaN  ...   NaN           G6       NaN
# 3              4       NaN     NaN  ...   NaN          NaN       NaN
# 4              5       NaN     NaN  ...   NaN          NaN       NaN
# ..           ...       ...     ...  ...   ...          ...       ...
# 886          887       NaN     NaN  ...   NaN          NaN       NaN
# ...

# %%
#ตาราง Mode ด้านบนมองเห็นไม่ชัดจึงแยกแสดงผลทีละตัวแทน
df['Pclass'].mode()
# Out:
# 0    3
# dtype: int64

# %%
#ตาราง Mode ด้านบนมองเห็นไม่ชัดจึงแยกแสดงผลทีละตัวแทน
df['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
#ตาราง Mode ด้านบนมองเห็นไม่ชัดจึงแยกแสดงผลทีละตัวแทน
df['SibSp'].mode()
# Out:
# 0    0
# dtype: int64

# %%
#ตาราง Mode ด้านบนมองเห็นไม่ชัดจึงแยกแสดงผลทีละตัวแทน
df['Parch'].mode()
# Out:
# 0    0
# dtype: int64

# %%
#ตาราง Mode ด้านบนมองเห็นไม่ชัดจึงแยกแสดงผลทีละตัวแทน
df['Fare'].mode()
# Out:
# 0    8.05
# dtype: float64

# %%
df.var()
# Out:
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %% [markdown]
# ## กราฟแสดงผลการกระจายตัว

# %%
# แสดงกราฟ histogram ดูการกระจายตัวของข้อมูล
# ดูที่ feature = Age //อายุผู้โดยสารเรือ

sns.set(rc={'figure.figsize':(12,8)})
sns.kdeplot(data['Age'])
sns.displot(data['Age'],kde=True, bins=20)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Age แบ่งตามคนที่รอดกับไม่รอด
sns.FacetGrid(data,hue='Survived',height = 5)\
 .map(sns.distplot,'Age')\
 . add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ดูที่ feature = SibSp //อายุผู้โดยสารเรือ

sns.set(rc={'figure.figsize':(12,8)})
sns.kdeplot(data['SibSp'])
sns.displot(data['SibSp'],kde=True, bins=20)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร SibSp แบ่งตามคนที่รอดกับไม่รอด
sns.FacetGrid(data,hue='Survived',height = 5)\
 .map(sns.distplot,'SibSp')\
 . add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ดูที่ feature = Parch //อายุผู้โดยสารเรือ

sns.set(rc={'figure.figsize':(12,8)})
sns.kdeplot(data['Parch'])
sns.displot(data['Parch'],kde=True, bins=20)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Parch แบ่งตามคนที่รอดกับไม่รอด
sns.FacetGrid(data,hue='Survived',height = 5)\
 .map(sns.distplot,'Parch')\
 . add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ดูที่ feature = Fare //อายุผู้โดยสารเรือ

sns.set(rc={'figure.figsize':(12,8)})
sns.kdeplot(data['Fare'])
sns.displot(data['Fare'],kde=True, bins=20)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Fare แบ่งตามคนที่รอดกับไม่รอด
sns.FacetGrid(data,hue='Survived',height = 5)\
 .map(sns.distplot,'Fare')\
 . add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Pclass แบ่งตามคนที่รอดกับไม่รอด
sns.FacetGrid(data,hue='Survived',height = 5)\
 .map(sns.distplot,'Pclass')\
 . add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร sex แบ่งตามคนที่รอดกับไม่รอด
sns.catplot(x="Sex", y="Survived", hue="Pclass", kind="bar", data=data)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร sex แบ่งตามคนที่รอดกับไม่รอด
sns.countplot(x="Pclass", hue="Survived", data=data)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Survived
sns.countplot(x="Pclass", data=data)

# %%
# ดูจำนวนคนในแต่ละ Class
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Survived
sns.countplot(x="Survived", data=data)

# %%
# ดูจำนวนคนในการรอดชีวิตและตาย
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสัมพันธ์ของตัวแปร Sex
sns.countplot(x="Sex", data=data)

# %%
# ดูจำนวนคนในแต่ละเพศ
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร sex แบ่งตามคนที่รอดกับไม่รอด
sns.countplot(x="Sex", hue="Survived", data=data)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร sex แบ่งตาม class
sns.countplot(x="Sex", hue="Pclass", data=data)

# %%
# ดูจำนวนผู้หญิงที่อยู่ที่คลาส 1
options = ['female']
rslt_df = df[(df['Pclass'] == 1) &
          df['Sex'].isin(options)]
rslt_df.shape
# Out:
# (94, 12)

# %%
# ดูจำนวนผู้หญิงที่อยู่ที่คลาส 1 และรอด
options = ['female']
rslt_df2 = df[(df['Pclass'] == 1) &
          df['Sex'].isin(options)&
          df['Survived'] ==1]
rslt_df2.shape
# Out:
# (91, 12)

# %%
# ดูจำนวนผู้ชายที่อยู่ที่คลาส 1
options = ['male']
rslt_df3 = df[(df['Pclass'] == 1) &
          df['Sex'].isin(options)]
rslt_df3.shape
# Out:
# (122, 12)

# %%
# ดูจำนวนผู้ชายที่อยู่ที่คลาส 1 และรอด
options = ['male']
rslt_df4 = df[(df['Pclass'] == 1) &
          df['Sex'].isin(options)&
          df['Survived'] ==1]
rslt_df4.shape
# Out:
# (45, 12)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสัมพันธ์ของตัวแปร Embarked
sns.countplot(x="Embarked", data=data)

# %%
# แสดงกราฟ histogram เพื่อดูแนวโน้มความสะมพันธ์ของตัวแปร Embarked แบ่งตามคนที่รอดกับไม่รอด
sns.countplot(x="Embarked", hue="Survived", data=data)

# %%
# ดูความสัมพันธ์ของข้อมูลจากตัวแปร 2 ตัวแปรเทียบกัน โดยมีการแบ่งตามคลาสของ survival ด้วย
sns.set_style('whitegrid')
sns.pairplot(data, hue='Survived', height = 5)
plt.show()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# ดูค่า correlation เพื่อดูการส่งผลต่อกัยของปัจจัยต่าง ๆ แบบเป็นคู่
sns.heatmap(data.corr(),
            square=True,
            linewidths=0.25,    
            #linecolor=(0,0,0),
            cmap='Blues',
           annot=True)

# %% [markdown]
# # Missing Val

# %%
## ดูว่ามีค่า null หรือไม่ 
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# ใช้ heatmap เพื่อแสดงว่าคอลัมน์ไหนมีข้อมูลหายบ้าง โดยแถบสีเหลืองๆคือข้อมูลที่หายไป
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# ดูค่า mean ของ Age
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
# เติมค่า Missing Value ด้วยค่าเฉลี่ยที่ได้จากด้านบน
df['Age'] = df['Age'].fillna(29.69911764705882)
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# ใช้ heatmap เพื่อลองดูว่าที่ Column Age ยังมีข้อมูลหายอยู่มั้ย 
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# drop คอละมน์ Cabin ทิ้งไป
df2 =df.drop(['Cabin'], axis=1)
df2
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %%
# ใช้ heatmap เพื่อลองดูว่าที่ Column Cabin ยังมีอยู่มั้ย 
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
## ดูว่ามีค่า null หรือไม่ 
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# จะเห็นว่าเหลือที่ Embarked เลยจะทำการ drop ที่ null row
df3 = df2.dropna()

# %%
## ดูว่ามีค่า null หรือไม่ 
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#null หมดแล้ววว

# %% [markdown]
# # Outliers

# %%
# ลองเช็คว่า df ยังเป็นข้อมูลแบบเริ่มต้น
df.shape
# Out:
# (891, 12)

# %%
# ดู Boxplot ของข้อมูลที่ยังไม่มีการตัด null value
boxplot = df.boxplot(grid=False, rot=45, fontsize=15)

# %%
# ดูว่าเป็นข้อมูลที่ตัด null ออกแล้วยัง สังเกตได้จากเหลือ 11 col และ 889 ข้อมูล(ถูกตัดออกไปตอน dropna ของ embarked)
df3.shape
# Out:
# (889, 11)

# %%
# หน้าตามันยังเหมือนเดิม
boxplot = df3.boxplot(grid=False, rot=45, fontsize=15)

# %%
# จะตัด col PassengerID ทิ้งเพราะว่าไม่ใช่ Numerical 
# drop คอลัมน์ PassengerID ทิ้งไป
df3 =df3.drop(['PassengerId'], axis=1)
df3.shape
# Out:
# (889, 10)

# %%
# จะตัด col Pclass ทิ้งเพราะว่าไม่ใช่ Numerical 
# drop คอลัมน์ Pclass ทิ้งไป
df3 =df3.drop(['Pclass'], axis=1)
df3.shape
# Out:
# (889, 9)

# %%
# จะตัด col Survived ทิ้งเพราะว่าไม่ใช่ Numerical 
# drop คอลัมน์ Survived ทิ้งไป
df3 =df3.drop(['Survived'], axis=1)
df3.shape
# Out:
# (889, 8)

# %%
# ลองพล็อตกราฟอีกครั้ง
boxplot = df3.boxplot(grid=False, rot=45, fontsize=15)

# %%
# IQR 

q1 = df3.quantile(0.25) # เลือกค่าที่เป็นจุดของ Q1
q3 = df3.quantile(0.75) # เลือกค่าที่เป็นจุดของ Q3
iqr = q3 - q1
iqr
# Out:
# Age      13.0000
# SibSp     1.0000
# Parch     0.0000
# Fare     23.1042
# dtype: float64

# %%
# คำนวณหาค่า lower outliers และ upper outliers
low_outlier = q1-1.5*iqr
upp_outlier = q3+1.5*iqr

# %%
# แสดงค่า lower outliers
low_outlier
# Out:
# Age       2.5000
# SibSp    -1.5000
# Parch     0.0000
# Fare    -26.7605
# dtype: float64

# %%
# แสดงค่า upper outliers
upp_outlier
# Out:
# Age      54.5000
# SibSp     2.5000
# Parch     0.0000
# Fare     65.6563
# dtype: float64

# %%
df3.shape
# Out:
# (889, 8)

# %%
# เลือกเฉพาะข้อมูลที่ไม่เกิน Outlier ของ Age
non_out = df3.loc[(df3['Age']>low_outlier['Age'])&(df3['Age']<upp_outlier['Age'])]
non_out.shape
# Out:
# (824, 8)

# %%
# แสดงค่าข้อมูลที่มีค่า Age เกินขอบเขต lower outliers
df_Age_low = df3[df3['Age'] < low_outlier['Age']]
df_Age_low.shape
# Out:
# (24, 8)

# %%
# แสดงค่าข้อมูลที่มีค่า Age เกินขอบเขต upper outliers
df_Age_upp = df3[df3['Age'] > upp_outlier['Age']]
df_Age_upp.shape
# Out:
# (41, 8)

# %%
#จาก 3 cell ด้านบนจะเห็นได้ว่าการเลือกคัดเฉพาะตัวที่ไม่เกิน Outliers ถูกต้องเพราะว่าพอเอาจำนวน row มาบวกกันจะได้ค่าเท่าเดิมก่อนตัดออก

# %%
# เลือกเฉพาะข้อมูลที่ไม่เกิน Outlier ของ SibSp
non_out = non_out.loc[(non_out['SibSp']>low_outlier['SibSp'])&(non_out['SibSp']<upp_outlier['SibSp'])]
non_out.shape
# Out:
# (785, 8)

# %%
# เลือกเฉพาะข้อมูลที่ไม่เกิน Outlier ของ Parch
non_out = non_out.loc[(non_out['Parch']>=low_outlier['Parch'])&(non_out['Parch']<=upp_outlier['Parch'])]
non_out.shape
# Out:
# (641, 8)

# %%
#ตอนแรกหากใช้ > กับ < ค่า Parch จะมีปัญหาเพราะว่าตัวที่จะไม่ออกจาก Outlier คือ 0 เท่านั้น พอคำนวณมาก็จะได้ขอบบนขอบล่างเป็น 0 แต่จริงๆต้องนับว่า 0 ยังไม่ออกเลยต้องทำการเปลี่ยนเป็น >= กับ <= 
# จากการตัดค่า Parch แล้วเหลือ 0 จึงลองมาดูว่าเกิดอะไรขึ้น จะเห็นว่าตัวที่ไม่ออก outlier คือ Parch = 0 
sns.boxplot(x='Parch', data=df3)

# %%
# เลือกเฉพาะข้อมูลที่ไม่เกิน Outlier ของ Fare
non_out = non_out.loc[(non_out['Fare']>low_outlier['Fare'])&(non_out['Fare']<upp_outlier['Fare'])]
non_out.shape
# Out:
# (577, 8)

# %%
# ลองพล็อตกราฟจากข้อมูลที่ตัด Outlier ออก
boxplot = non_out.boxplot(grid=False, rot=45, fontsize=15)

# %%
# ลองพล็อตกราฟจากคำสั่งตัด Outlier ของ sns
boxplot = df3.boxplot(grid=False, rot=45, fontsize=15, showfliers = False)

# %%
# ผลที่ได้ค่อนข้างต่างกันแต่ Range ที่ข้อมูลกระจายไปถึงจะเหมือนกัน แต่แบบจากข้อมูลที่ตัดเองจะมีตัวใหม่นับเป็น Outlier ส่วนอันที่ใช้ sns จะไม่มี

# %% [markdown]
# # Transformation

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %%
## ดูว่ามีค่า null หรือไม่ 
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# drop cabin
dft = df2
#dft.drop('Cabin',axis=1,inplace=True)
dft
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %%
# ลองแสดง data ขึ้นมาดู
dft.shape
# Out:
# (891, 11)

# %%
## ดูว่ามีค่า null หรือไม่ 
dft.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# จะเหลือที่ Embarked เลยจะทำการ drop ที่ null row
dft = dft.dropna()

# %%
dft.shape
# Out:
# (889, 11)

# %%
# One_hot_encoding
dummies = pd.get_dummies(dft.Sex)
merged = pd.concat([dft,dummies],axis='columns')
merged
# Out:
#      PassengerId  Survived  Pclass  ... Embarked female  male
# 0              1         0       3  ...        S      0     1
# 1              2         1       1  ...        C      1     0
# 2              3         1       3  ...        S      1     0
# 3              4         1       1  ...        S      1     0
# 4              5         0       3  ...        S      0     1
# ..           ...       ...     ...  ...      ...    ...   ...
# 886          887         0       2  ...        S      0     1
# 887          888         1       1  ...        S      1     0
# 888          889         0       3  ...        S      1     0
# 889          890         1       1  ...        C      0     1
# 890          891         0       3  ...        Q      0     1
#
# [889 rows x 13 columns]

# %%
# label encoding
# เปลี่ยน Type ก่อน
dft.Sex = pd.Categorical(dft.Sex)
dft['SexCat'] = dft.Sex.cat.codes
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# จะได้ col SexCat ขึ้นมาซึ่งเป็นการเปลี่ยนจาก male -> 1, female -> 0
dft
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Embarked  SexCat
# 0              1         0       3  ...   7.2500        S       1
# 1              2         1       1  ...  71.2833        C       0
# 2              3         1       3  ...   7.9250        S       0
# 3              4         1       1  ...  53.1000        S       0
# 4              5         0       3  ...   8.0500        S       1
# ..           ...       ...     ...  ...      ...      ...     ...
# 886          887         0       2  ...  13.0000        S       1
# 887          888         1       1  ...  30.0000        S       0
# 888          889         0       3  ...  23.4500        S       0
# 889          890         1       1  ...  30.0000        C       1
# 890          891         0       3  ...   7.7500        Q       1
#
# [889 rows x 12 columns]

# %%
# drop col ที่ไม่ใช้
final = dft.drop(['PassengerId','Name','Ticket','Embarked','Sex','Pclass'],axis='columns')
final
# Out:
#      Survived        Age  SibSp  Parch     Fare  SexCat
# 0           0  22.000000      1      0   7.2500       1
# 1           1  38.000000      1      0  71.2833       0
# 2           1  26.000000      0      0   7.9250       0
# 3           1  35.000000      1      0  53.1000       0
# 4           0  35.000000      0      0   8.0500       1
# ..        ...        ...    ...    ...      ...     ...
# 886         0  27.000000      0      0  13.0000       1
# 887         1  19.000000      0      0  30.0000       0
# 888         0  29.699118      1      2  23.4500       0
# 889         1  26.000000      0      0  30.0000       1
# 890         0  32.000000      0      0   7.7500       1
#
# [889 rows x 6 columns]

# %%
X = final.drop('Survived', axis='columns')

# %%
y = final.Survived

# %% [markdown]
# #  Feature scaling

# %%
# ทำการแบ่งข้อมูลก่อนเป็นชุด test(30%) train(70%) 
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# ทำการ scaling ด้วยวิธี standardization ที่ Input แต่ Output ไม่ต้องทำ
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_train
# Out:
# array([[ 0.00627074, -0.47473241, -0.45521828,  0.07980737,  0.72423049],
#        [-1.32578257,  0.40671105, -0.45521828, -0.40736542,  0.72423049],
#        [ 0.00627074,  0.40671105, -0.45521828, -0.34140784, -1.38077589],
#        ...,
#        [ 3.79196551, -0.47473241, -0.45521828, -0.02271949,  0.72423049],
#        [ 0.00627074, -0.47473241, -0.45521828, -0.47896403,  0.72423049],
#        [-0.34738956,  0.40671105,  1.91420238,  0.21471632,  0.72423049]])

# %%
X_test
# Out:
# array([[-1.17526057e+00, -4.74732414e-01, -4.55218277e-01,
#         -4.76827366e-01, -1.38077589e+00],
#        [ 6.27074178e-03,  6.57681533e+00,  1.91420238e+00,
#          7.88267994e-01,  7.24230491e-01],
#        [ 4.80481456e-01,  4.06711054e-01,  1.91420238e+00,
#          1.82276404e+00, -1.38077589e+00],
#        ...,
#        [ 6.27074178e-03,  4.06711054e-01,  7.29492050e-01,
#         -3.25259855e-01,  7.24230491e-01],
#        [-3.47389557e-01, -4.74732414e-01, -4.55218277e-01,
#         -4.93317787e-01,  7.24230491e-01],
#        [ 1.45887447e+00,  4.06711054e-01, -4.55218277e-01,
#          9.35480165e-01, -1.38077589e+00]])

# %%
# ลองทำ Normalization ดู
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_traintt = sc.fit_transform(X_train)
X_testtt = sc.transform(X_test)
X_traintt
# Out:
# array([[0.36792055, 0.        , 0.        , 0.06831545, 1.        ],
#        [0.14551395, 0.125     , 0.        , 0.02194234, 1.        ],
#        [0.36792055, 0.125     , 0.        , 0.02822072, 0.        ],
#        ...,
#        [1.        , 0.        , 0.        , 0.0585561 , 1.        ],
#        [0.36792055, 0.        , 0.        , 0.01512699, 1.        ],
#        [0.30887158, 0.125     , 0.33333333, 0.08115719, 1.        ]])

# %%
X_testtt
# Out:
# array([[0.17064589, 0.        , 0.        , 0.01533038, 0.        ],
#        [0.36792055, 1.        , 0.33333333, 0.13575256, 1.        ],
#        [0.44709726, 0.125     , 0.33333333, 0.2342244 , 0.        ],
#        ...,
#        [0.36792055, 0.125     , 0.16666667, 0.02975782, 1.        ],
#        [0.30887158, 0.        , 0.        , 0.01376068, 1.        ],
#        [0.61045489, 0.125     , 0.        , 0.14976542, 0.        ]])

# %% [markdown]
# # Feature Reduction

# %%
# Correlation
plt.figure(figsize=(15,8))
sns.heatmap(final.corr(),
            square=True,
            linewidths=0.25,    
            linecolor=(0,0,0),
           cmap=sns.color_palette("coolwarm"),
           annot=True)

# %%
# เตรียมข้อมูล Input
input_vars = [ 'Age', 'SibSp', 'Parch', 'Fare', 'SexCat']

# %%
# Wrapper Methods - Forward Feature Selection
from sklearn.feature_selection import f_regression
fstat, pval = f_regression(final[input_vars], final.Survived)
fstat
# Out:
# array([  4.9736859 ,   1.02897829,   6.17546233,  61.83888505,
#        368.1547322 ])

# %%
f_value_threshold = 3  # ปรับได้ โดยปรับจนได้จำนวนปัจจัยที่ต้องการ 
updated_vars = []
for i in range(0,len(input_vars)-1):
    if fstat[i] >= f_value_threshold:
        updated_vars.append(final[input_vars].columns[i])
updated_vars
# Out:
# ['Age', 'Parch', 'Fare']

# %%
# จะได้ว่าปัจจัยที่คัดออกมาแล้วเหลือ 3 ตัว ได้แก่ 'Age', 'Parch', 'Fare'

# %%
# Random Forest

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(max_depth=10,n_estimators=100)
model.fit(final[input_vars],final.Survived)

# ต้องการให้เหลือ 3 ปัจจัย
n_features = 3

# Plot feature importance
features = final[input_vars].columns
importances = model.feature_importances_
indices = np.argsort(importances)[-n_features:]  # sort top n features
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
